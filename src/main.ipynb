# %% [markdown]
# - 模組一: 五日線、布林軌道
# - 進場:突破上軌並且隔天沒有回跌昨天漲幅過半
# - 出場:收盤價破布林軌道上軌

# %%
# %reload_ext autoreload
# %autoreload 2

# 使用範例
import pandas as pd
from lib.backtest.strategy_one import backtest_strategy



df1 = pd.read_csv("../data/TPE-sample1.csv", encoding="utf-8")
df1 = backtest_strategy(df1)
df1
# Out:
#                日期    開盤價    最高價    最低價    收盤價     成交量      MA5     BB_MA  \
# 0      2012/06/01   7200   7210   7075   7100  148958      NaN       NaN
# 1      2012/06/04   6927   6930   6832   6866  136278      NaN       NaN
# 2      2012/06/05   6949   7005   6925   6973  119982      NaN       NaN
# 3      2012/06/06   6989   7055   6958   7013  119994      NaN       NaN
# 4      2012/06/07   7135   7146   7020   7045  109350   6999.4       NaN
# ...           ...    ...    ...    ...    ...     ...      ...       ...
# 1256   2017/07/11  10232  10356  10228  10342  141931  10264.6  10252.40
# 1257   2017/07/12  10346  10383  10330  10339  114330  10272.2  10266.10
# 1258   2017/07/13  10393  10442  10371  10420  143543  10302.8  10283.45
# 1259   2017/07/14  10420  10424  10391  10403   79383  10342.8  10296.30
# 1260   2017/07/17  10458  10480  10414  10436  137588  10388.0  10306.15
#
#          BB_STD      BB_Upper      BB_Lower  prev_gain  ret    cus  position  \
# 0           NaN           NaN           NaN        NaN  0.0    0.0         0
# 1           NaN           NaN           NaN  -0.032958  0.0    0.0         0
# 2           NaN           NaN           NaN   0.015584  0.0    0.0         0
# 3           NaN           NaN           NaN   0.005736  0.0    0.0         0
# 4           NaN           NaN           NaN   0.004563  0.0    0.0         0
# ...         ...           ...           ...        ...  ...    ...       ...
# 1256  88.406597  10429.213193  10075.586807   0.012929  0.0  514.0         0
# 1257  78.514430  10423.128861  10109.071139  -0.000290  0.0  514.0         0
# 1258  71.636124  10426.722247  10140.177753   0.007834  0.0  514.0         0
# 1259  68.671683  10433.643365  10158.956635  -0.001631  0.0  514.0         0
# 1260  73.946122  10454.042244  10158.257756   0.003172  0.0  514.0         0
#
#         BH
# 0        0
# 1     -234
# 2     -127
# 3      -87
# 4      -55
# ...    ...
# 1256  3242
# 1257  3239
# 1258  3320
# 1259  3303
# 1260  3336
#
# [1261 rows x 16 columns]

# %%
# %reload_ext autoreload
# %autoreload 2

from lib.performance_analysis import calculate_strategy_one_performance

# 從 position 欄位產生進出場訊號
# 當 position 從 0 變成 1 時，是進場訊號
df1['entry'] = (df1['position'] == 1) & (df1['position'].shift(1) == 0)

# 當 position 從 1 變成 0 時，是出場訊號
df1['exit'] = (df1['position'] == 0) & (df1['position'].shift(1) == 1)

# 計算策略績效
performance = calculate_strategy_one_performance(
    df1,
)

# 印出績效報告
performance_df = pd.DataFrame([performance])

# 存成csv檔案
# performance_df.T.to_csv('module_one.csv',
#                         header=['Value'],  # 欄位名稱 (y 軸)
#                         index_label='Metric')  # 列名 (x 軸)

performance_df.T
# Out:
#                                0
# 最終權益 (Mark-to-Market)      514.0
# 淨利或淨損 (已實現)                514.0
# 最大回撤 (MDD)                 113.0
# 總獲利 (已實現)                  755.0
# 總損失 (已實現)                 -241.0
# 總交易次數                         24
# 賺錢交易次數                        14
# 虧錢交易次數                        10
# 勝率                        58.33%
# 單次交易最大獲利                   172.0
# 單次交易最大損失                   -45.0
# 獲利交易中的平均獲利             53.928571
# 損失交易中的平均損失                 -24.1
# 賺賠比                       2.2377
# 最長的連續性獲利的次數                    5
# 最長的連續性損失的次數                    3

# %% [markdown]
# - 模組二: 五日線和二十日線
# - 進場:五日線在二十日線之上
# - 出場:(開盤價格 + 收盤價格) / 2的值小於五日線

# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
from lib.backtest.strategy_two import backtest_strategy_two

df2 = pd.read_csv("../data/TPE-sample1.csv", encoding="utf-8")
df2 = backtest_strategy_two(df2)
df2
# Out:
#                日期    開盤價    最高價    最低價    收盤價     成交量      MA5      MA20  ret  \
# 0      2012/06/01   7200   7210   7075   7100  148958      NaN       NaN  0.0
# 1      2012/06/04   6927   6930   6832   6866  136278      NaN       NaN  0.0
# 2      2012/06/05   6949   7005   6925   6973  119982      NaN       NaN  0.0
# 3      2012/06/06   6989   7055   6958   7013  119994      NaN       NaN  0.0
# 4      2012/06/07   7135   7146   7020   7045  109350   6999.4       NaN  0.0
# ...           ...    ...    ...    ...    ...     ...      ...       ...  ...
# 1256   2017/07/11  10232  10356  10228  10342  141931  10264.6  10252.40  0.0
# 1257   2017/07/12  10346  10383  10330  10339  114330  10272.2  10266.10  0.0
# 1258   2017/07/13  10393  10442  10371  10420  143543  10302.8  10283.45  0.0
# 1259   2017/07/14  10420  10424  10391  10403   79383  10342.8  10296.30  0.0
# 1260   2017/07/17  10458  10480  10414  10436  137588  10388.0  10306.15  0.0
#
#         cus  position    BH
# 0       0.0         0     0
# 1       0.0         0  -234
# 2       0.0         0  -127
# 3       0.0         0   -87
# 4       0.0         0   -55
# ...     ...       ...   ...
# 1256  759.0         0  3242
# 1257  752.0         1  3239
# 1258  833.0         1  3320
# 1259  816.0         1  3303
# 1260  849.0         1  3336
#
# [1261 rows x 12 columns]

# %%
# %reload_ext autoreload
# %autoreload 2

from lib.performance_analysis import calculate_strategy_one_performance

# 計算策略績效
performance_two = calculate_strategy_one_performance(df2)

# 印出績效報告
performance_two_df = pd.DataFrame([performance_two])

# 存成csv檔案
# performance_two_df.T.to_csv('module_two.csv',
#                         header=['Value'],  # 欄位名稱 (y 軸)
#                         index_label='Metric')  # 列名 (x 軸)

performance_two_df.T
# Out:
#                                0
# 最終權益 (Mark-to-Market)      849.0
# 淨利或淨損 (已實現)                759.0
# 最大回撤 (MDD)                 714.0
# 總獲利 (已實現)                 2039.0
# 總損失 (已實現)                -1280.0
# 總交易次數                         39
# 賺錢交易次數                        20
# 虧錢交易次數                        19
# 勝率                        51.28%
# 單次交易最大獲利                   332.0
# 單次交易最大損失                  -138.0
# 獲利交易中的平均獲利                101.95
# 損失交易中的平均損失            -67.368421
# 賺賠比                      1.51332
# 最長的連續性獲利的次數                    3
# 最長的連續性損失的次數                    4

# %% [markdown]
# - 模組三: 裸K
# - 進場:過去三天、五天、十天均價程不斷墊高
# - 出場:近三天均價低於近五天均價

# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
from lib.backtest.strategy_three import backtest_strategy_three

df3 = pd.read_csv("../data/TPE-sample1.csv", encoding="utf-8")
df3 = backtest_strategy_three(df3)
df3
# Out:
#                日期    開盤價    最高價    最低價    收盤價     成交量           MA3      MA5  \
# 0      2012/06/01   7200   7210   7075   7100  148958           NaN      NaN
# 1      2012/06/04   6927   6930   6832   6866  136278           NaN      NaN
# 2      2012/06/05   6949   7005   6925   6973  119982   6979.666667      NaN
# 3      2012/06/06   6989   7055   6958   7013  119994   6950.666667      NaN
# 4      2012/06/07   7135   7146   7020   7045  109350   7010.333333   6999.4
# ...           ...    ...    ...    ...    ...     ...           ...      ...
# 1256   2017/07/11  10232  10356  10228  10342  141931  10251.666667  10264.6
# 1257   2017/07/12  10346  10383  10330  10339  114330  10297.000000  10272.2
# 1258   2017/07/13  10393  10442  10371  10420  143543  10367.000000  10302.8
# 1259   2017/07/14  10420  10424  10391  10403   79383  10387.333333  10342.8
# 1260   2017/07/17  10458  10480  10414  10436  137588  10419.666667  10388.0
#
#          MA10  ret    cus  position    BH
# 0         NaN  0.0    0.0         0     0
# 1         NaN  0.0    0.0         0  -234
# 2         NaN  0.0    0.0         0  -127
# 3         NaN  0.0    0.0         0   -87
# 4         NaN  0.0    0.0         0   -55
# ...       ...  ...    ...       ...   ...
# 1256  10263.9  0.0  925.0         0  3242
# 1257  10271.7  0.0  925.0         0  3239
# 1258  10284.0  0.0  952.0         1  3320
# 1259  10299.1  0.0  935.0         1  3303
# 1260  10313.8  0.0  968.0         1  3336
#
# [1261 rows x 13 columns]

# %%
# %reload_ext autoreload
# %autoreload 2

from lib.performance_analysis import calculate_strategy_one_performance

# 計算策略績效
performance_three = calculate_strategy_one_performance(df3)

# 印出績效報告
performance_three_df = pd.DataFrame([performance_three])

# 存成csv檔案
# performance_three_df.T.to_csv('module_three.csv',
#                         header=['Value'],  # 欄位名稱 (y 軸)
#                         index_label='Metric')  # 列名 (x 軸)

performance_three_df.T
# Out:
#                                 0
# 最終權益 (Mark-to-Market)       968.0
# 淨利或淨損 (已實現)                 925.0
# 最大回撤 (MDD)                  832.0
# 總獲利 (已實現)                  4772.0
# 總損失 (已實現)                 -3847.0
# 總交易次數                          96
# 賺錢交易次數                         45
# 虧錢交易次數                         51
# 勝率                         46.88%
# 單次交易最大獲利                    326.0
# 單次交易最大損失                   -298.0
# 獲利交易中的平均獲利             106.044444
# 損失交易中的平均損失             -75.431373
# 賺賠比                       1.40584
# 最長的連續性獲利的次數                     4
# 最長的連續性損失的次數                     5
